# %%
## Instructions:
# Import the csv data into IFROG and run.

import numpy as np
import Run
import FROG_plot

# %matplotlib inline

IFROG = np.genfromtxt('test_bin256.txt',dtype=complex,delimiter='\t')
IFROG = IFROG / np.amax(IFROG)

Best_Trace_w, Best_Pulse, Best_Gate, G = Run.FROG_Loop(IFROG, Pulse=[], Gate=[], max_iter=100, G_min=10**-5)
ax1, ax2, ax3, ax4, ax5, ax6, ax7 = FROG_plot.FROG_plot(Best_Trace_w, Best_Pulse, Best_Gate, IFROG, G, Cen_Wave = 743.6233, Wave_PPx=0.7432871, Delay_PPx=1)
# Out:
# C:\Users\Hegmann\Documents\Daniel\Recorded Data\10 - 21st Stability Test With Trebino Data\FROG_lib.py:32: RuntimeWarning: invalid value encountered in true_divide
#   Ew /= np.absolute(Ew)
